# %% [markdown]
# # House Price Preiction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data =pd.read_csv("D:\Coding Related\Programs in different languages\Python Programs\House_Price_Noisy_Dataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\netus\AppData\Local\Temp\ipykernel_18284\16404151.py:1: SyntaxWarning: invalid escape sequence '\C'
#   data =pd.read_csv("D:\Coding Related\Programs in different languages\Python Programs\House_Price_Noisy_Dataset.csv")

# %%
data.head()
# Out:
#       price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420.0         4          2        3      yes        no       no
# 1  12250000  8960.0         4          4        4      yes        no       no
# 2  12250000  9960.0         3          2        2      yes        no      yes
# 3  12215000  7500.0         4          2        2      yes        no      yes
# 4  11410000  7420.0         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  gender
# 0              no             yes        2      yes        furnished    male
# 1              no             yes        3       no        furnished    male
# 2              no              no        2      yes   semi-furnished    male
# 3              no             yes        3      yes        furnished  female
# 4              no             yes        2       no              NaN    male

# %%
data.shape
# Out:
# (545, 14)
